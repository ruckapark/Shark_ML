# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'Testmodel_basic.ipynb',
#  'TrainedModel.keras',
#  '__init__.py']

# %%
from tensorflow import keras

# %%
model = keras.models.load_model('TrainedModel.keras', compile=False)

# %%
model.compile(optimizer=keras.optimizers.legacy.Adam(), 
              loss='sparse_categorical_crossentropy', 
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.compile(optimizer=keras.optimizers.legacy.Adam(),
#       2               loss='sparse_categorical_crossentropy',
#       3               metrics=['accuracy'])
#
# File ~\anaconda3\envs\SharkEgg\lib\site-packages\keras\src\optimizers\__init__.py:115, in LegacyOptimizerWarning.__init__(self, *args, **kwargs)
#     114 def __init__(self, *args, **kwargs):
# --> 115     raise ImportError(
#     116         "`keras.optimizers.legacy` is not supported in Keras 3. When using "
#     117         "`tf.keras`, to continue using a `tf.keras.optimizers.legacy` "
#     118         "optimizer, you can install the `tf_keras` package (Keras 2) and "
#     119         "set the environment variable `TF_USE_LEGACY_KERAS=True` to "
# ...
